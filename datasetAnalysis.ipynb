# %%
# %config IPCompleter.greedy=True

# %%
import numpy as np
import pandas as pd

# %%
from dataExplore import *

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
# Out:
# <style>.container { width:100% !important; }</style>

# %%
realData = getReal()
fakeData = getFake()

# %% [markdown]
# ### What the data looks like

# %%
print(realData.head())
print(fakeData.head())
# Out:
#                                                title                                               text       subject                date
# 0  As U.S. budget fight looms, Republicans flip t...  WASHINGTON (Reuters) - The head of a conservat...  politicsNews  December 31, 2017
# 1  U.S. military to accept transgender recruits o...  WASHINGTON (Reuters) - Transgender people will...  politicsNews  December 29, 2017
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...  WASHINGTON (Reuters) - The special counsel inv...  politicsNews  December 31, 2017
# 3  FBI Russia probe helped by Australian diplomat...  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews  December 30, 2017
# 4  Trump wants Postal Service to charge 'much mor...  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews  December 29, 2017
#                                                title                                               text subject               date
# ...

# %% [markdown]
# Most of the real news have a format similar to "REGION (Reuters) - NEWS". Although it is likely that news with a source such as Reuters will be real, including it in the text may lead to classifying news without a similar format as fake news. So we get rid of the "REGION (Reuters) - " part.

# %% [markdown]
# ### Exploration by text

# %%
textExplore(list(realData['text']), list(fakeData['text']), 'text')
# Out:
# Real mean = 385.6400989867862 	SD = 273.99980657651633
# Fake mean = 423.1979046888974 	SD = 408.3801941877828
# Done

# %% [markdown]
# Looking at the lengths of texts in either classes, we can see that the data is right skewed. Although we don't have a truly normal distribution of lengths of texts, we can see that most of the data lies within 3 standard deviations.

# %% [markdown]
# ### Exploration by title

# %%
textExplore(list(realData['title']), list(fakeData['title']), 'title')
# Out:
# Real mean = 9.954475416725032 	SD = 1.7007068715332099
# Fake mean = 14.732805246795282 	SD = 4.335006802684303
# Done

# %% [markdown]
# ### Exploration by date

# %%
dateExplore(dateToInt(list(realData['date'])), dateToInt(list(fakeData['date'])))

# %% [markdown]
# ### Exploration by subject

# %%
subjectExplore(list(realData['subject']), list(fakeData['subject']))

# %% [markdown]
# The "politicsNews" category can be considered equivalent to politics. However, the real news doesn't include categories included by the fake news. Using this in our training could lead to an unnecessary bias as in reality we can have real news with the subject Middle-east, or have fake news with the subject worldnews. This bias would overfit the model to this dataset and may not work too well if deployed.
